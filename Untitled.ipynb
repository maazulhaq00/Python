# %%
5++
# Out:
#   File "<ipython-input-1-ab0dc7fb017e>", line 1
#     5++
#        ^
# SyntaxError: invalid syntax

# %%
i=5
c=a
d=i+c
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d07f36883fe3> in <module>
#       1 i=5
# ----> 2 c=a
#       3 d=i+c
#       4 print(d)
#
# NameError: name 'a' is not defined

# %%
i=5
c='a'
d=i+c
print(d)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-07fcc6aadfd7> in <module>
#       1 i=5
#       2 c='a'
# ----> 3 d=i+c
#       4 print(d)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
i=5
c='a'
d=i+(int)c
print(d)
# Out:
#   File "<ipython-input-4-7692a9a765bc>", line 3
#     d=i+(int)c
#              ^
# SyntaxError: invalid syntax
